# %%
import pandas as pd 
import matplotlib.pyplot as plt

df = pd.read_csv("data/expe1/v1/002_002_2025-03-24-17h47.37.040_ExG.csv")

df = df[['ch3', 'ch4']]

df.plot()
plt.title('Subject 002_002')
plt.show()

# %%
df = pd.read_csv("data/expe1/v1/003_002_2025-03-24-18h23.20.403_ExG.csv")

df = df[['ch3', 'ch4']]

df.plot()
plt.title('Subject 003_002')
plt.show()

# %%
df = pd.read_csv("data/expe1/v1/004_002_2025-03-24-18h53.49.288_ExG.csv")

df = df[['ch3', 'ch4']]

df.plot()
plt.title('Subject 004_002')
plt.show()
